# %% [markdown]
# # Jupyter Notebook Exercise
#
# This notebook demonstrates basic notebook operations.
#
# - Code Cell
# - Markdown Cell

# %%
print("Hello from Jupyter Notebook!")
# Out:
# Hello from Jupyter Notebook!
